# %%
def charger_json(nom_fichier):
    try:
        with open(nom_fichier, "r") as f:
            return json.load(f)
    except:
        return[]

def sauvegarder_json(nom_fichier, contenu):
    with open(nom_fichier, "w"):
        json.dump(contenu, f, indent=4)

def charger_membres():
    data = charger_json("membres.json")
    return [Membre(**m) for m in data]

def sauvegarder_membres(list_membres):
    data = [m.__dict__ for m in list_membres]
    sauvegarde_json(".membres.json", data)

def charger_livres():
    data = charger_json("livres.json")
    return [Livre(**l) for m in data]

def sauvegarder_livres(list_livres):
    data = [l.__dict__ for l in list_livres]
    sauvegarder_json(livres.json, data)

def charger_emprunts():
    data = charger_json("empreunts.json")
    return [emprun(**e) for e in list_emprunts]

def sauvegarder_empreunts(list_emprunts):
    data = [e.__dict__ for e in list_emprunts]
    sauvegarder_json(emprunts.json, data)
