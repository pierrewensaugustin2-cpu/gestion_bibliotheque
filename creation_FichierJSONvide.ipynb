# %%
import json

# Creation des fichiers vides si absents
for f in ["membres.json", "livres.json", "empunts.json","bibliothecaires.json"]:
    try:
        open(f, "x").write("[]")
    except:
        pass
print("Fichiers prets !")
# Out:
# Fichiers prets !
